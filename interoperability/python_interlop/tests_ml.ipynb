# %% [markdown]
# # Modèle Linéaire : Classification
#
# ### Importation de la lib :

# %%
from interoperability.python_interlop.wrapper.my_lib import MyModel
import numpy as np

model_type = "ml"
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from interoperability.python_interlop.wrapper.my_lib import MyModel
#       2 import numpy as np
#       4 model_type = "ml"
#
# File ~/esgi/3BigData/interoperability/python_interlop/wrapper/my_lib.py:6
#       3 import ctypes
#       4 from interoperability.python_interlop.wrapper.import_lib import init_lib
# ----> 6 my_lib = init_lib()
#       9 class MyModel:
#      10     def __init__(self, model_type: str, size: (int, tuple), is_classification: bool = False, is_3_classes: bool = False,
#      11                  cluster_size: int = 0, gamma: float = 0, ):
#
# File ~/esgi/3BigData/interoperability/python_interlop/wrapper/import_lib.py:8, in init_lib()
#       4 def init_lib():
#       7     lib_path = "/home/adam/esgi/3BigData/mylib/target/release/mylib.so"
# ----> 8     my_lib = ctypes.cdll.LoadLibrary(lib_path)
#       9     # --------------------------init_linear_model--------------------------
#      10     # pub extern "C" fn init_linear_model(input_count: u32) -> *mut LinearModel;
#      11     my_lib.init_linear_model.argtypes = [ctypes.c_uint32, ctypes.c_bool]
#
# File /usr/lib/python3.12/ctypes/__init__.py:460, in LibraryLoader.LoadLibrary(self, name)
#     459 def LoadLibrary(self, name):
# --> 460     return self._dlltype(name)
#
# File /usr/lib/python3.12/ctypes/__init__.py:379, in CDLL.__init__(self, name, mode, handle, use_errno, use_last_error, winmode)
#     376 self._FuncPtr = _FuncPtr
#     378 if handle is None:
# --> 379     self._handle = _dlopen(self._name, mode)
#     380 else:
#     381     self._handle = handle
#
# OSError: /home/adam/esgi/3BigData/mylib/target/release/mylib.so: cannot open shared object file: No such file or directory

# %% [markdown]
# ### Linear simple :

# %%
X = np.array([
    [1, 1],
    [2, 3],
    [3, 3]
])
Y = np.array([
    1,
    -1,
    -1
])

with MyModel(model_type, 2, is_classification=True) as model:
    model.train(X, Y, 0.01, 10_000)
    model.print_classification(4, 4, 0.05)
# Out:
# Initializing the model...
# Training the model...
# Printing the training data...
# Deleting last model...

# %% [markdown]
# ### Linear Multiple :

# %%
X = np.concatenate(
    [np.random.random((50, 2)) * 0.9 + np.array([1, 1]), np.random.random((50, 2)) * 0.9 + np.array([2, 2])])
Y = np.concatenate([np.ones((50, 1)), np.ones((50, 1)) * -1.0])

with MyModel(model_type, 2, is_classification=True) as model:
    model.train(X, Y, 0.01, 10_000)
    model.print_classification(4, 4, 0.01)
# Out:
# Initializing the model...
# Training the model...
# Printing the training data...
# Deleting last model...

# %% [markdown]
# ### XOR :

# %%
X = np.array([[1, 0], [0, 1], [0, 0], [1, 1]])
Y = np.array([1, 1, -1, -1])

with MyModel(model_type, 2, is_classification=True) as model :
    model.train(X, Y, 0.1, 1_000)
    model.print_classification(1, 1, 0.01)
# Out:
# Initializing the model...
# Training the model...
# Printing the training data...
# Deleting last model...

# %% [markdown]
# ### Cross

# %%
X = np.random.random((500, 2)) * 2.0 - 1.0
Y = np.array([1 if abs(p[0]) <= 0.3 or abs(p[1]) <= 0.3 else -1 for p in X])

with MyModel(model_type, 2, is_classification=True) as model:
    model.train(X, Y, 0.1, 1_000)
    model.print_classification(1, 1, 0.01, -1, -1)
# Out:
# Initializing the model...
# Training the model...
# Printing the training data...
# Deleting last model...

# %% [markdown]
# ### Multi linear 3 classes

# %%
X = np.random.random((500, 2)) * 2.0 - 1.0
Y = np.array([[1, 0, 0] if -p[0] - p[1] - 0.5 > 0 > p[1] and p[0] - p[1] - 0.5 < 0 else
              [0, 1, 0] if -p[0] - p[1] - 0.5 < 0 < p[1] and p[0] - p[1] - 0.5 < 0 else
              [0, 0, 1] if -p[0] - p[1] - 0.5 < 0 < p[0] - p[1] - 0.5 and p[1] < 0 else
              [0, 0, 0] for p in X])

X = X[[not np.all(arr == [0, 0, 0]) for arr in Y]]
Y = Y[[not np.all(arr == [0, 0, 0]) for arr in Y]]

with MyModel(model_type, 2, is_classification=True, is_3_classes=True) as model :
    model.train(X, Y, 0.01, 10_000)
    model.print_classification(1, 1, 0.01, -1, -1)
# Out:
# Initializing the model...
# Training the model...
# Printing the training data...
# Deleting last model...

# %% [markdown]
# ### Multicross :

# %%
X = np.random.random((1000, 2)) * 2.0 - 1.0
Y = np.array([[1, 0, 0] if abs(p[0] % 0.5) <= 0.25 < abs(p[1] % 0.5) else [0, 1, 0] if abs(
    p[0] % 0.5) > 0.25 >= abs(p[1] % 0.5) else [0, 0, 1] for p in X])

with MyModel(model_type, 2, is_classification=True, is_3_classes=True) as model :
    model.train(X, Y, 0.01, 1_000)
    model.print_classification(1, 1, 0.01, -1, -1)
# Out:
# Initializing the model...
# Training the model...
# Printing the training data...
# Deleting last model...

# %% [markdown]
# # Régression
# ### Linéaire simple 2D

# %%
X = np.array([
    [1],
    [2]
])
Y = np.array([
    2,
    3
])

with MyModel(model_type, 1) as model:
    model.train(X, Y, 0.01, 1_000)
    model.print_regression()
# Out:
# Initializing the model...
# Training the model...
# Printing the training data...
# Deleting last model...

# %% [markdown]
# ### Non Linéaire Simple :

# %%
X = np.array([
      [1],
      [2],
      [3]
])
Y = np.array([
      2,
      3,
      2.5
])

with MyModel(model_type, 1) as model :
    model.train(X, Y, 0.01, 1_0)
    model.print_regression()
# Out:
# Initializing the model...
# Training the model...
# Printing the training data...
# Deleting last model...

# %% [markdown]
# ### Linéaire simple 3D

# %%
X = np.array([
      [1, 1],
      [2, 2],
      [3, 3]
])
Y = np.array([
      1,
      2,
      3
])

with MyModel(model_type, 2) as model:
    model.train(X, Y, 0.01, 1_000_000)
    model.print_regression_3d()
# Out:
# Initializing the model...
# Training the model...
# Deleting last model...

# %% [markdown]
# ### Linéaire tricky 3D

# %%
X = np.array([
      [1, 1],
      [2, 2],
      [3, 3]
])
Y = np.array([
      1,
      2,
      3
])

with MyModel(model_type, 2) as model:
    model.train(X, Y, 0.1, 1_000)
    model.print_regression_3d()
# Out:
# Initializing the model...
# Training the model...
# Deleting last model...

# %% [markdown]
# ### Non linéaire simple 3D

# %%
X = np.array([
      [1, 0],
      [0, 1],
      [1, 1],
      [0, 0],
])
Y = np.array([
      2,
      1,
      -2,
      -1
])

with MyModel(model_type, 2) as model:
    model.train(X, Y, 0.1, 1_000)
    model.print_regression_3d()
# Out:
# Initializing the model...
# Training the model...
# Deleting last model...
