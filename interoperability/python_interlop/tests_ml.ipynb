# %% [markdown]
# # Modèle Linéaire : Classification
#
# ### Importation de la lib :

# %%
from interoperability.python_interlop.wrapper.my_lib import MyModel
import numpy as np

model_type = "ml"

# %% [markdown]
# ### Linear simple :

# %%
X = np.array([
    [1, 1],
    [2, 3],
    [3, 3]
])
Y = np.array([
    1,
    -1,
    -1
])

with MyModel(model_type, 2, is_classification=True) as model:
    model.train(X, Y, 0.01, 1_000)
    model.print_classification(4, 4, 0.05)
# Out:
# Initializing the model...
# Training the model...
# Printing the training data...
# Deleting last model...

# %% [markdown]
# ### Linear Multiple :

# %%
X = np.concatenate(
    [np.random.random((50, 2)) * 0.9 + np.array([1, 1]), np.random.random((50, 2)) * 0.9 + np.array([2, 2])])
Y = np.concatenate([np.ones((50, 1)), np.ones((50, 1)) * -1.0])

model = MyModel(model_type, 2, is_classification=True)

model.train(X, Y, 0.001, 1_000)

model.print_classification(4, 4, 0.01)
# Out:
# Deleting last model...

# %% [markdown]
# ### XOR :

# %%
X = np.array([[1, 0], [0, 1], [0, 0], [1, 1]])
Y = np.array([1, 1, -1, -1])

model = MyModel(model_type, 2, is_classification=True)

model.train(X, Y, 0.1, 1_000)

model.print_classification(1, 1, 0.01)

# %% [markdown]
# ### Cross

# %%
X = np.random.random((500, 2)) * 2.0 - 1.0
Y = np.array([1 if abs(p[0]) <= 0.3 or abs(p[1]) <= 0.3 else -1 for p in X])

model = MyModel(model_type, 2, is_classification=True)

model.train(X, Y, 0.1, 1_000)

model.print_classification(1, 1, 0.01, -1, -1)

# %% [markdown]
# ### Multi linear 3 classes

# %%
X = np.random.random((500, 2)) * 2.0 - 1.0
Y = np.array([[1, 0, 0] if -p[0] - p[1] - 0.5 > 0 > p[1] and p[0] - p[1] - 0.5 < 0 else
              [0, 1, 0] if -p[0] - p[1] - 0.5 < 0 < p[1] and p[0] - p[1] - 0.5 < 0 else
              [0, 0, 1] if -p[0] - p[1] - 0.5 < 0 < p[0] - p[1] - 0.5 and p[1] < 0 else
              [0, 0, 0] for p in X])

X = X[[not np.all(arr == [0, 0, 0]) for arr in Y]]
Y = Y[[not np.all(arr == [0, 0, 0]) for arr in Y]]

model = MyModel(model_type, 2, is_classification=True, is_3_classes=True)
model.train(X, Y, 0.001, 1000000)
model.print_classification(1, 1, 0.01, -1, -1)

# %% [markdown]
# ### Multicross :

# %%
X = np.random.random((1000, 2)) * 2.0 - 1.0
Y = np.array([[1, 0, 0] if abs(p[0] % 0.5) <= 0.25 < abs(p[1] % 0.5) else [0, 1, 0] if abs(
    p[0] % 0.5) > 0.25 >= abs(p[1] % 0.5) else [0, 0, 1] for p in X])

model = MyModel(model_type, 2, is_classification=True, is_3_classes=True)

model.train(X, Y, 0.001, 1_000)

model.print_classification(1, 1, 0.01, -1, -1)

# %% [markdown]
# # Régression
# ### Linéaire simple 2D

# %%
X = np.array([
    [1],
    [2]
])
Y = np.array([
    2,
    3
])

model = MyModel(model_type, 1)

model.train(X, Y, 0.1, 1_000)

model.print_regression()

# %% [markdown]
# ### Non Linéaire Simple :

# %%
X = np.array([
      [1],
      [2],
      [3]
])
Y = np.array([
      2,
      3,
      2.5
])

model = MyModel(model_type, 1)

model.train(X, Y, 0.1, 1_0)

model.print_regression()

# %% [markdown]
# ### Linéaire simple 3D

# %%
X = np.array([
      [1, 1],
      [2, 2],
      [3, 3]
])
Y = np.array([
      1,
      2,
      3
])

model = MyModel(model_type, 2)

model.train(X, Y, 0.1, 1_000)

model.print_regression()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 16
#      12 model = MyModel(model_type, 2)
#      14 model.train(X, Y, 0.1, 1_000)
# ---> 16 model.print_regression()
#
# File ~\RustroverProjects\3BigData\interoperability\python_interlop\wrapper.py:259, in MyModel.print_regression(self, start, size)
#     256 ax = plt.figure().add_subplot(111, projection='3d')
#     258 ax.scatter(self.train_data[0], self.train_data[1], self.train_data[2])
# --> 259 ax.plot_surface(x[0], x[1], y)
#     261 plt.show()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\mpl_toolkits\mplot3d\axes3d.py:1979, in Axes3D.plot_surface(self, X, Y, Z, norm, vmin, vmax, lightsource, **kwargs)
#    1909 """
#    1910 Create a surface plot.
#    1911
#    (...)
#    1974     Other keyword arguments are forwarded to `.Poly3DCollection`.
#    1975 """
#    1977 had_data = self.has_data()
# -> 1979 if Z.ndim != 2:
#    1980     raise ValueError("Argument Z must be 2-dimensional.")
#    1982 Z = cbook._to_unmasked_float_array(Z)
#
# AttributeError: 'list' object has no attribute 'ndim'

# %% [markdown]
# ### Linéaire tricky 3D

# %%
X = np.array([
      [1, 1],
      [2, 2],
      [3, 3]
])
Y = np.array([
      1,
      2,
      3
])

model = MyModel(model_type, 2)

model.train(X, Y, 0.1, 1_000)

model.print_regression()

# %% [markdown]
# ### Non linéaire simple 3D

# %%
X = np.array([
      [1, 0],
      [0, 1],
      [1, 1],
      [0, 0],
])
Y = np.array([
      2,
      1,
      -2,
      -1
])

model = MyModel(model_type, 2)

model.train(X, Y, 0.1, 1_000)

model.print_regression()
