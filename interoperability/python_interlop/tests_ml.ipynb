# %% [markdown]
# # Modèle Linéaire : Classification
#
# ### Importation de la lib :

# %%
from interoperability.python_interlop.wrapper.my_lib import MyModel
import numpy as np

model_type = "ml"

# %% [markdown]
# ### Linear simple :

# %%
X = np.array([
    [1, 1],
    [2, 3],
    [3, 3]
])
Y = np.array([
    1,
    -1,
    -1
])

with MyModel(model_type, 2, is_classification=True) as model:
    model.train(X, Y, learning_rate=0.01, epochs= 1000_000)
    model.print_classification(4, 4, 0.05)
# Out:
# Initializing the model...
# Training the model...
# Printing the classification results...
# Printing the training data...
# Deleting last model...

# %% [markdown]
# ### Linear Multiple :

# %%
X = np.concatenate(
    [np.random.random((50, 2)) * 0.9 + np.array([1, 1]), np.random.random((50, 2)) * 0.9 + np.array([2, 2])])
Y = np.concatenate([np.ones((50, 1)), np.ones((50, 1)) * -1.0])

with MyModel(model_type, 2, is_classification=True) as model:
    model.train(X, Y, learning_rate= 0.01,epochs= 10_000)
    model.print_classification(4, 4, 0.01)
# Out:
# Initializing the model...
# Training the model...
# Printing the classification results...
# Printing the training data...
# Deleting last model...

# %% [markdown]
# ### XOR :

# %%
X = np.array([[1, 0], [0, 1], [0, 0], [1, 1]])
Y = np.array([1, 1, -1, -1])

with MyModel(model_type, 2, is_classification=True) as model :
    model.train(X, Y, learning_rate= 0.1, epochs= 1_000)
    model.print_classification(1, 1, 0.01)
# Out:
# Initializing the model...
# Training the model...
# Printing the classification results...
# Printing the training data...
# Deleting last model...

# %% [markdown]
# ### Cross

# %%
X = np.random.random((500, 2)) * 2.0 - 1.0
Y = np.array([1 if abs(p[0]) <= 0.3 or abs(p[1]) <= 0.3 else -1 for p in X])

with MyModel(model_type, 2, is_classification=True) as model:
    model.train(X, Y, learning_rate= 0.1, epochs= 1_000)
    model.print_classification(1, 1, 0.01, -1, -1)
# Out:
# Initializing the model...
# Training the model...
# Printing the classification results...
# Printing the training data...
# Deleting last model...

# %% [markdown]
# ### Multi linear 3 classes

# %%
X = np.random.random((500, 2)) * 2.0 - 1.0
Y = np.array([[1, 0, 0] if -p[0] - p[1] - 0.5 > 0 > p[1] and p[0] - p[1] - 0.5 < 0 else
              [0, 1, 0] if -p[0] - p[1] - 0.5 < 0 < p[1] and p[0] - p[1] - 0.5 < 0 else
              [0, 0, 1] if -p[0] - p[1] - 0.5 < 0 < p[0] - p[1] - 0.5 and p[1] < 0 else
              [0, 0, 0] for p in X])

X = X[[not np.all(arr == [0, 0, 0]) for arr in Y]]
Y = Y[[not np.all(arr == [0, 0, 0]) for arr in Y]]

with MyModel(model_type, 2, is_classification=True, is_3_classes=True) as model :
    model.train(X, Y, learning_rate= 0.01, epochs= 10_000)
    model.print_classification(1, 1, 0.01, -1, -1)
# Out:
# Initializing the model...
# Training the model...
# Printing the classification results...
# Printing the training data...
# Deleting last model...

# %% [markdown]
# ### Multicross :

# %%
X = np.random.random((1000, 2)) * 2.0 - 1.0
Y = np.array([[1, 0, 0] if abs(p[0] % 0.5) <= 0.25 < abs(p[1] % 0.5) else [0, 1, 0] if abs(
    p[0] % 0.5) > 0.25 >= abs(p[1] % 0.5) else [0, 0, 1] for p in X])

with MyModel(model_type, 2, is_classification=True, is_3_classes=True) as model :
    model.train(X, Y, learning_rate= 0.01, epochs= 1_000)
    model.print_classification(1, 1, 0.01, -1, -1)
# Out:
# Initializing the model...
# Training the model...
# Printing the classification results...
# Printing the training data...
# Deleting last model...

# %% [markdown]
# # Régression
# ### Linéaire simple 2D

# %%
X = np.array([
    [1],
    [2]
])
Y = np.array([
    2,
    3
])

with MyModel(model_type, 1) as model:
    model.train(X, Y, learning_rate=0.01, epochs= 1_000)
    model.print_regression()
# Out:
# Initializing the model...
# Training the model...
# Printing the training data...
# Deleting last model...

# %% [markdown]
# ### Non Linéaire Simple :

# %%
X = np.array([
      [1],
      [2],
      [3]
])
Y = np.array([
      2,
      3,
      2.5
])

with MyModel(model_type, 1) as model :
    model.train(X, Y, learning_rate= 0.01, epochs= 1_0)
    model.print_regression()
# Out:
# Initializing the model...
# Training the model...
# Printing the training data...
# Deleting last model...

# %% [markdown]
# ### Linéaire simple 3D

# %%
X = np.array([
      [1, 1],
      [2, 2],
      [3, 3]
])
Y = np.array([
      1,
      2,
      3
])

with MyModel(model_type, 2) as model:
    model.train(X, Y,learning_rate= 0.01,epochs= 1_000_000)
    model.print_regression_3d()
# Out:
# Initializing the model...
# Training the model...
# Deleting last model...

# %% [markdown]
# ### Linéaire tricky 3D

# %%
X = np.array([
      [1, 1],
      [2, 2],
      [3, 3]
])
Y = np.array([
      1,
      2,
      3
])

with MyModel(model_type, 2) as model:
    model.train(X, Y, learning_rate=0.1, epochs= 1_000)
    model.print_regression_3d()
# Out:
# Initializing the model...
# Training the model...
# Deleting last model...

# %% [markdown]
# ### Non linéaire simple 3D

# %%
X = np.array([
      [1, 0],
      [0, 1],
      [1, 1],
      [0, 0],
])
Y = np.array([
      2,
      1,
      -2,
      -1
])

with MyModel(model_type, 2) as model:
    model.train(X, Y, learning_rate= 0.1, epochs= 1_000)
    model.print_regression_3d()
# Out:
# Initializing the model...
# Training the model...
# Deleting last model...
