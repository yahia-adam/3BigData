# %% [markdown]
# # Modèle RBF : Classification
#
# ### Importation de la lib :

# %%
from interoperability.python_interlop.wrapper.my_lib import MyModel
import numpy as np

model_type = "rbf"

# %% [markdown]
# ### Linear simple :

# %%
X = np.array([
    [1, 1],
    [2, 3],
    [3, 3]
])
Y = np.array([
    1,
    -1,
    -1
])

with MyModel(model_type, size=2, cluster_size=2, gamma=1.0, is_classification=True) as model:
    model.train(x_train=X, y_train=Y, learning_rate=0.01, sample_count=3, epochs=1000)
    model.print_classification(4, 4, 0.01)
# Out:
# Initializing the model...
# Training the model...
# Printing the training data...
# Deleting last model...

# %% [markdown]
# ### Linear Multiple :

# %%
X = np.concatenate(
    [np.random.random((50, 2)) * 0.9 + np.array([1, 1]), np.random.random((50, 2)) * 0.9 + np.array([2, 2])])
Y = np.concatenate([np.ones((50, 1)), np.ones((50, 1)) * -1.0])

with MyModel(model_type, size=2, cluster_size=10, gamma=1.0, is_classification=True) as model:
     model.train(x_train=X, y_train=Y, learning_rate=0.01, sample_count=len(X), epochs=30_000)
     model.print_classification(4, 4, 0.01)
# Out:
# Initializing the model...
# Training the model...
# Printing the training data...
# Deleting last model...

# %% [markdown]
# ### XOR :

# %%
X = np.array([[1, 0], [0, 1], [0, 0], [1, 1]])
Y = np.array([1, 1, -1, -1])

with MyModel(model_type, size=2, cluster_size=5, gamma=1.0, is_classification=True) as model:
    model.train(x_train=X, y_train=Y, learning_rate=0.0001, sample_count=5, epochs=400_000)
    model.print_classification(1.2, 1.2, 0.01, -0.2, -0.2)
# Out:
# Initializing the model...
# Training the model...
# Printing the training data...
# Deleting last model...

# %% [markdown]
# ### Cross

# %%
X = np.random.random((500, 2)) * 2.0 - 1.0
Y = np.array([1 if abs(p[0]) <= 0.3 or abs(p[1]) <= 0.3 else -1 for p in X])

with MyModel(model_type, size=2, cluster_size=32, gamma=2.0, is_classification=True) as model:
    model.train(x_train=X, y_train=Y, learning_rate=0.01, sample_count=500, epochs=1_000_000)
    model.print_classification(1, 1, 0.01, -1, -1)
# Out:
# Initializing the model...
# Training the model...
# Printing the training data...
# Deleting last model...

# %% [markdown]
# ### Multi linear 3 classes

# %%
X = np.random.random((300, 2)) * 2.0 - 1.0
Y = np.array([[1, 0, 0] if -p[0] - p[1] - 0.5 > 0 > p[1] and p[0] - p[1] - 0.5 < 0 else
              [0, 1, 0] if -p[0] - p[1] - 0.5 < 0 < p[1] and p[0] - p[1] - 0.5 < 0 else
              [0, 0, 1] if -p[0] - p[1] - 0.5 < 0 < p[0] - p[1] - 0.5 and p[1] < 0 else
              [0, 0, 0] for p in X])

X = X[[not np.all(arr == [0, 0, 0]) for arr in Y]]
Y = Y[[not np.all(arr == [0, 0, 0]) for arr in Y]]

    # let input_dim = 2;
    # let cluster_num = 6;
    # let gamma = 1.0;
    # 
    # let rbf_model: *mut RadialBasisFunctionNetwork = init_rbf(input_dim, cluster_num, gamma);
    # 
    # let iterations_count = 1000;
    # let alpha = 0.01;

with MyModel(model_type, size=2, cluster_size=200, gamma=10.0, is_classification=True, is_3_classes=True) as model:
    model.train(x_train=X, y_train=Y, learning_rate=0.01, sample_count=300, epochs=100_000)
    model.print_classification(1, 1, 0.01, -1, -1)
# Out:
# Initializing the model...
# Training the model...

# %% [markdown]
# ### Multicross :

# %%
X = np.random.random((1000, 2)) * 2.0 - 1.0
Y = np.array([[1, 0, 0] if abs(p[0] % 0.5) <= 0.25 < abs(p[1] % 0.5) else [0, 1, 0] if abs(
    p[0] % 0.5) > 0.25 >= abs(p[1] % 0.5) else [0, 0, 1] for p in X])

X = (X - X.mean(axis=0)) / X.std(axis=0)

with MyModel(model_type, size=2, cluster_size=32, gamma=10.0, is_classification=True, is_3_classes=True) as model:
    model.train(x_train=X, y_train=Y, learning_rate=0.001, sample_count=1000, epochs=10_000_000)
    model.print_classification(1, 1, 0.01, -1, -1)
# Out:
# Initializing the model...
# Training the model...

# %% [markdown]
# # Régression
# ### Linéaire simple 2D

# %%
X = np.array([
    [1],
    [2],
    [3],
])
Y = np.array([
    2,
    3,
    4
])

with MyModel(model_type, size=1, cluster_size=2, gamma=0.01) as model:
    model.train(x_train=X, y_train=Y, sample_count=3)
    model.print_regression()
# Out:
# Initializing the model...
# Training the model...
# Printing the training data...
# Deleting last model...

# %% [markdown]
# ### Non Linéaire Simple :

# %%
X = np.array([
      [1],
      [2],
      [3]
])
Y = np.array([
      2,
      3,
      2.5
])


with MyModel(model_type, size=1, cluster_size=3, gamma=2.0, is_classification=False) as model:
    model.train(x_train=X, y_train=Y, sample_count=5)
    model.print_regression()
# Out:
# Initializing the model...
# Training the model...
# Printing the training data...
# Deleting last model...

# %% [markdown]
# ### Linéaire simple 3D

# %%
X = np.array([
      [1, 1],
      [2, 2],
      [3, 3]
])
Y = np.array([
      1,
      2,
      3
])

with MyModel(model_type, size=2, cluster_size=5, gamma=1.0) as model:
    model.train(x_train=X, y_train=Y, sample_count=5)
    model.print_regression_3d()
# Out:
# Initializing the model...
# Training the model...
# Deleting last model...

# %% [markdown]
# ### Linéaire tricky 3D

# %%
X = np.array([
      [1, 1],
      [2, 2],
      [3, 3]
])
Y = np.array([
      1,
      2,
      3
])

with MyModel(model_type, size=2, cluster_size=3, gamma=0.5, is_classification=False) as model:
    model.train(x_train=X, y_train=Y, sample_count=3)
    model.print_regression_3d()
# Out:
# Initializing the model...
# Training the model...
# Deleting last model...

# %% [markdown]
# ### Non linéaire simple 3D

# %%
X = np.array([
      [1, 0],
      [0, 1],
      [1, 1],
      [0, 0],
])
Y = np.array([
      2,
      1,
      -2,
      -1
])

with MyModel(model_type, size=2, cluster_size=4, gamma=1.0, is_classification=False) as model:
    model.train(x_train=X, y_train=Y, sample_count=4)
    model.print_regression_3d()
# Out:
# Initializing the model...
# Training the model...
# Deleting last model...
