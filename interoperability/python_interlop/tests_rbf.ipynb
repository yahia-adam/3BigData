# %% [markdown]
# # Modèle RBF : Classification
#
# ### Importation de la lib :

# %%
from interoperability.python_interlop.wrapper.my_lib import MyModel
import numpy as np

model_type = "rbf"

# %% [markdown]
# ### Linear simple :

# %%
X = np.array([
    [1, 1],
    [2, 3],
    [3, 3]
])
Y = np.array([
    1,
    -1,
    -1
])

with MyModel(model_type, size=2, cluster_size=2, gamma=1.0, is_classification=True) as model:
    model.train(x_train=X, y_train=Y, learning_rate=0.01, sample_count=3, epochs=1000)
    model.print_classification(4, 4, 0.01)
# Out:
# Initializing the model...
# Training the model...
# Printing the training data...
# Deleting last model...

# %% [markdown]
# ### Linear Multiple :

# %%
X = np.concatenate(
    [np.random.random((50, 2)) * 0.9 + np.array([1, 1]), np.random.random((50, 2)) * 0.9 + np.array([2, 2])])
Y = np.concatenate([np.ones((50, 1)), np.ones((50, 1)) * -1.0])

with MyModel(model_type, size=2, cluster_size=10, gamma=1.0, is_classification=True) as model:
     model.train(x_train=X, y_train=Y, learning_rate=0.01, sample_count=len(X), epochs=30_000)
     model.print_classification(4, 4, 0.01)
# Out:
# Initializing the model...
# Training the model...
# Printing the training data...
# Deleting last model...

# %% [markdown]
# ### XOR :

# %%
X = np.array([[1, 0], [0, 1], [0, 0], [1, 1]])
Y = np.array([1, 1, -1, -1])

with MyModel(model_type, size=2, cluster_size=5, gamma=1.0, is_classification=True) as model:
    model.train(x_train=X, y_train=Y, learning_rate=0.0001, sample_count=5, epochs=400_000)
    model.print_classification(1.2, 1.2, 0.01, -0.2, -0.2)
# Out:
# Initializing the model...
# Training the model...
# Printing the training data...
# Deleting last model...

# %% [markdown]
# ### Cross

# %%
X = np.random.random((500, 2)) * 2.0 - 1.0
Y = np.array([1 if abs(p[0]) <= 0.3 or abs(p[1]) <= 0.3 else -1 for p in X])

with MyModel(model_type, size=2, cluster_size=32, gamma=2.0, is_classification=True) as model:
    model.train(x_train=X, y_train=Y, learning_rate=0.0001, sample_count=500, epochs=1_000_000)
    model.print_classification(1, 1, 0.01, -1, -1)
# Out:
# Initializing the model...
# Training the model...

# %% [markdown]
# ### Multi linear 3 classes

# %%
X = np.random.random((500, 2)) * 2.0 - 1.0
Y = np.array([[1, 0, 0] if -p[0] - p[1] - 0.5 > 0 > p[1] and p[0] - p[1] - 0.5 < 0 else
              [0, 1, 0] if -p[0] - p[1] - 0.5 < 0 < p[1] and p[0] - p[1] - 0.5 < 0 else
              [0, 0, 1] if -p[0] - p[1] - 0.5 < 0 < p[0] - p[1] - 0.5 and p[1] < 0 else
              [0, 0, 0] for p in X])

X = X[[not np.all(arr == [0, 0, 0]) for arr in Y]]
Y = Y[[not np.all(arr == [0, 0, 0]) for arr in Y]]

input_dim = len(X)
with MyModel(model_type, input_dim, cluster_size=6, gamma=1.0, is_classification=True) as model :
    model.train(X, Y, 0.01, 10_000)
    model.print_classification(1, 1, 0.01, -1, -1)

# %% [markdown]
# ### Multicross :

# %%
X = np.random.random((1000, 2)) * 2.0 - 1.0
Y = np.array([[1, 0, 0] if abs(p[0] % 0.5) <= 0.25 < abs(p[1] % 0.5) else [0, 1, 0] if abs(
    p[0] % 0.5) > 0.25 >= abs(p[1] % 0.5) else [0, 0, 1] for p in X])

input_dim = len(X)

with MyModel(model_type, input_dim, cluster_size=32, gamma=1.0, is_classification=True) as model :
    model.train(X, Y, 0.001, 10000000)
    model.print_classification(1, 1, 0.01, -1, -1)

# %% [markdown]
# # Régression
# ### Linéaire simple 2D

# %%
X = np.array([
    [1],
    [2],
    [3],
    [4],
    [5]
])
Y = np.array([
    2,
    3,
    4,
    5,
    6
])

input_dim = len(X)
model = MyModel(model_type, input_dim, cluster_size=3, gamma=0.1, is_classification=False)

model.train(X, Y, 0.1, 1_000)
print("train")
model.print_regression()

# %% [markdown]
# ### Non Linéaire Simple :

# %%
X = np.array([
      [1],
      [2],
      [3]
])
Y = np.array([
      2,
      3,
      2.5
])

model = MyModel("rbf", 2, cluster_size=2, gamma=1.0, is_classification=False)

model.train(X, Y, 0.01, 10_000_000)

model.print_regression()
# Out:
# Initializing the model...
# ---------------------------------------------------------------------------
# ArgumentError                             Traceback (most recent call last)
# Cell In[6], line 12
#       1 X = np.array([
#       2       [1],
#       3       [2],
#       4       [3]
#       5 ])
#       6 Y = np.array([
#       7       2,
#       8       3,
#       9       2.5
#      10 ])
# ---> 12 model = MyModel(model_type, (1,2,1))
#      14 model.train(X, Y, 0.01, 10_000_000)
#      16 model.print_regression()
#
# File ~\OneDrive\Online Sessions\3iabd1\projet annuel\3BigData\interoperability\python_interlop\wrapper\my_lib.py:36, in MyModel.__init__(self, model_type, size, is_classification, is_3_classes, cluster_size, gamma)
#      33 print("Initializing the model...")
#      35 if not self.__is_3_classes or self.__type != "ml":
# ---> 36     self.model = self._init_model()
#      37 else:
#      38     # Initialise les modèles linéaires en tant que regression pour pouvoir
#      39     # comparer les résultat de chaque One vs Rest
#      40     self.__is_classification = False
#
# File ~\OneDrive\Online Sessions\3iabd1\projet annuel\3BigData\interoperability\python_interlop\wrapper\my_lib.py:55, in MyModel._init_model(self)
#      53     return my_lib.init_mlp(raw_size, len(self.__dims), self.__is_classification)
#      54 elif self.__type == "rbf":
# ---> 55     return my_lib.init_rbf(self.__dims, self.__cluster_size, self.__gamma)
#
# ArgumentError: argument 1: TypeError: wrong type

# %% [markdown]
# ### Linéaire simple 3D

# %%
X = np.array([
      [1, 1],
      [2, 2],
      [3, 3]
])
Y = np.array([
      1,
      2,
      3
])

model = MyModel(model_type, (2,1))

model.train(X, Y, 0.1, 1_000)

model.print_regression()

# %% [markdown]
# ### Linéaire tricky 3D

# %%
X = np.array([
      [1, 1],
      [2, 2],
      [3, 3]
])
Y = np.array([
      1,
      2,
      3
])

model = MyModel(model_type, (2,1))

model.train(X, Y, 0.1, 1_000)

model.print_regression()

# %% [markdown]
# ### Non linéaire simple 3D

# %%
X = np.array([
      [1, 0],
      [0, 1],
      [1, 1],
      [0, 0],
])
Y = np.array([
      2,
      1,
      -2,
      -1
])

model = MyModel(model_type, (2,2,1))

model.train(X, Y, 0.1, 1_000)

model.print_regression()
