# %% [markdown]
# # Modèle RBF : Classification
#
# ### Importation de la lib :

# %%
from interoperability.python_interlop.wrapper.my_lib import MyModel
import numpy as np

model_type = "rbf"

# %% [markdown]
# ### Linear simple :

# %%
X = np.array([
    [1, 1],
    [2, 3],
    [3, 3]
])
Y = np.array([
    1,
    -1,
    -1
])

input_dim = len(X)

model = MyModel(model_type, input_dim, cluster_size=2, gamma=1.0, is_classification=True)
model.train(X, Y, 0.01, 100)
model.print_classification(4, 4, 0.01)
# Out:
# Initializing the model...
# Deleting last model...
# Training the model...
# Printing the training data...

# %% [markdown]
# ### Linear Multiple :

# %%
X = np.concatenate(
    [np.random.random((50, 2)) * 0.9 + np.array([1, 1]), np.random.random((50, 2)) * 0.9 + np.array([2, 2])])
Y = np.concatenate([np.ones((50, 1)), np.ones((50, 1)) * -1.0])

input_dim = len(X)

model = MyModel(model_type, input_dim, cluster_size=10, gamma=1.0, is_classification=True)

model.train(X, Y, 0.01, 1000)

model.print_classification(4, 4, 0.01)
# Out:
# Initializing the model...
# Deleting last model...
# Training the model...
# Printing the training data...

# %% [markdown]
# ### XOR :

# %%
X = np.array([[1, 0], [0, 1], [0, 0], [1, 1]])
Y = np.array([1, 1, -1, -1])

input_dim = len(X)

model = MyModel(model_type, input_dim, cluster_size=4, gamma=2.0, is_classification=True)

model.train(X, Y, 0.01, 1000)

model.print_classification(1.2, 1.2, 0.01, -0.2, -0.2)
# Out:
# Initializing the model...
# Deleting last model...
# Training the model...
# Printing the training data...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 12
#       8 model.train(X, Y, 0.01, 1000)
#      10 model.print_classification(1.2, 1.2, 0.01, -0.2, -0.2)
# ---> 12 model.delete()
#
# AttributeError: 'MyModel' object has no attribute 'delete'

# %% [markdown]
# ### Cross

# %%
X = np.random.random((500, 2)) * 2.0 - 1.0
Y = np.array([1 if abs(p[0]) <= 0.3 or abs(p[1]) <= 0.3 else -1 for p in X])

input_dim = len(X)

with MyModel(model_type, 2, is_classification=True) as model:
    model.train(X, Y, 0.1, 1_000)
    model.print_classification(1, 1, 0.01, -1, -1)
# Out:
# Initializing the model...
# Training the model...
# Training failed due to exception: access violation reading 0x00000241B1FA9000
# Deleting last model...
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[23], line 7
#       4 input_dim = len(X)
#       6 with MyModel(model_type, 2, is_classification=True) as model:
# ----> 7     model.train(X, Y, 0.1, 1_000)
#       8     model.print_classification(1, 1, 0.01, -1, -1)
#
# File ~\OneDrive\Online Sessions\3iabd1\projet annuel\3BigData\interoperability\python_interlop\wrapper\my_lib.py:84, in MyModel.train(self, x, y, learning_rate, epochs)
#      82 if not self.__is_3_classes or self.__type != "ml":
#      83     y_flat_ptr = y.flatten().astype(ctypes.c_float).ctypes.data_as(ctypes.POINTER(ctypes.c_float))
# ---> 84     self._train_model(x_flat_ptr, y_flat_ptr, data_size, sample_count, learning_rate, epochs)
#      85 else:
#      86     y = np.transpose(y)
#
# File ~\OneDrive\Online Sessions\3iabd1\projet annuel\3BigData\interoperability\python_interlop\wrapper\my_lib.py:105, in MyModel._train_model(self, x_flat_ptr, y_flat_ptr, data_size, sample_count, learning_rate, epochs, index)
#     103     elif self.__type == "rbf":
#     104         if self.__is_classification:
# --> 105             my_lib.train_rbf_rosenblatt(self.model, x_flat_ptr, y_flat_ptr, data_size, learning_rate,
#     106                                         epochs, sample_count)
#     107         # else:
#     108         #     my_lib.train_rbf_regression(self.model, x_flat_ptr, y_flat_ptr, inputs_size, sample_count)
#     109 except Exception as e:
#
# OSError: exception: access violation reading 0x00000241B1FA9000

# %% [markdown]
# ### Multi linear 3 classes

# %%
X = np.random.random((500, 2)) * 2.0 - 1.0
Y = np.array([[1, 0, 0] if -p[0] - p[1] - 0.5 > 0 > p[1] and p[0] - p[1] - 0.5 < 0 else
              [0, 1, 0] if -p[0] - p[1] - 0.5 < 0 < p[1] and p[0] - p[1] - 0.5 < 0 else
              [0, 0, 1] if -p[0] - p[1] - 0.5 < 0 < p[0] - p[1] - 0.5 and p[1] < 0 else
              [0, 0, 0] for p in X])

X = X[[not np.all(arr == [0, 0, 0]) for arr in Y]]
Y = Y[[not np.all(arr == [0, 0, 0]) for arr in Y]]

input_dim = len(X)
with MyModel(model_type, input_dim, cluster_size=6, gamma=1.0, is_classification=True) as model :
    model.train(X, Y, 0.01, 10_000)
    model.print_classification(1, 1, 0.01, -1, -1)
# Out:
# Initializing the model...
# Training the model...
# Training failed due to exception: access violation reading 0x00000241B15BF000
# Deleting last model...
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[24], line 12
#      10 input_dim = len(X)
#      11 with MyModel(model_type, input_dim, cluster_size=6, gamma=1.0, is_classification=True) as model :
# ---> 12     model.train(X, Y, 0.01, 10_000)
#      13     model.print_classification(1, 1, 0.01, -1, -1)
#
# File ~\OneDrive\Online Sessions\3iabd1\projet annuel\3BigData\interoperability\python_interlop\wrapper\my_lib.py:84, in MyModel.train(self, x, y, learning_rate, epochs)
#      82 if not self.__is_3_classes or self.__type != "ml":
#      83     y_flat_ptr = y.flatten().astype(ctypes.c_float).ctypes.data_as(ctypes.POINTER(ctypes.c_float))
# ---> 84     self._train_model(x_flat_ptr, y_flat_ptr, data_size, sample_count, learning_rate, epochs)
#      85 else:
#      86     y = np.transpose(y)
#
# File ~\OneDrive\Online Sessions\3iabd1\projet annuel\3BigData\interoperability\python_interlop\wrapper\my_lib.py:105, in MyModel._train_model(self, x_flat_ptr, y_flat_ptr, data_size, sample_count, learning_rate, epochs, index)
#     103     elif self.__type == "rbf":
#     104         if self.__is_classification:
# --> 105             my_lib.train_rbf_rosenblatt(self.model, x_flat_ptr, y_flat_ptr, data_size, learning_rate,
#     106                                         epochs, sample_count)
#     107         # else:
#     108         #     my_lib.train_rbf_regression(self.model, x_flat_ptr, y_flat_ptr, inputs_size, sample_count)
#     109 except Exception as e:
#
# OSError: exception: access violation reading 0x00000241B15BF000

# %% [markdown]
# ### Multicross :

# %%
X = np.random.random((1000, 2)) * 2.0 - 1.0
Y = np.array([[1, 0, 0] if abs(p[0] % 0.5) <= 0.25 < abs(p[1] % 0.5) else [0, 1, 0] if abs(
    p[0] % 0.5) > 0.25 >= abs(p[1] % 0.5) else [0, 0, 1] for p in X])

input_dim = len(X)

with MyModel(model_type, input_dim, cluster_size=32, gamma=1.0, is_classification=True) as model :
    model.train(X, Y, 0.001, 10000000)
    model.print_classification(1, 1, 0.01, -1, -1)

# %% [markdown]
# # Régression
# ### Linéaire simple 2D

# %%
X = np.array([
    [1],
    [2],
    [3],
    [4],
    [5]
])
Y = np.array([
    2,
    3,
    4,
    5,
    6
])

input_dim = len(X)
model = MyModel(model_type, input_dim, cluster_size=3, gamma=0.1, is_classification=False)

model.train(X, Y, 0.1, 1_000)
print("train")
model.print_regression()
# Out:
# Initializing the model...
# Training the model...
# train
# Printing the training data...

# %% [markdown]
# ### Non Linéaire Simple :

# %%
X = np.array([
      [1],
      [2],
      [3]
])
Y = np.array([
      2,
      3,
      2.5
])

model = MyModel("rbf", 2, cluster_size=2, gamma=1.0, is_classification=False)

model.train(X, Y, 0.01, 10_000_000)

model.print_regression()
# Out:
# Initializing the model...
# Deleting last model...
# Training the model...
# Printing the training data...

# %% [markdown]
# ### Linéaire simple 3D

# %%
X = np.array([
      [1, 1],
      [2, 2],
      [3, 3]
])
Y = np.array([
      1,
      2,
      3
])

model = MyModel(model_type, (2,1))

model.train(X, Y, 0.1, 1_000)

model.print_regression()

# %% [markdown]
# ### Linéaire tricky 3D

# %%
X = np.array([
      [1, 1],
      [2, 2],
      [3, 3]
])
Y = np.array([
      1,
      2,
      3
])

model = MyModel(model_type, (2,1))

model.train(X, Y, 0.1, 1_000)

model.print_regression()

# %% [markdown]
# ### Non linéaire simple 3D

# %%
X = np.array([
      [1, 0],
      [0, 1],
      [1, 1],
      [0, 0],
])
Y = np.array([
      2,
      1,
      -2,
      -1
])

model = MyModel(model_type, (2,2,1))

model.train(X, Y, 0.1, 1_000)

model.print_regression()
