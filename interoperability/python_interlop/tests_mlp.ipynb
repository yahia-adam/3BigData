# %% [markdown]
# # Modèle Perceptron Multi-Couche : Classification
#
# ### Importation de la lib :

# %%
from interoperability.python_interlop.wrapper.my_lib import MyModel
import numpy as np

model_type = "mlp"

# %% [markdown]
# ### Linear simple :

# %%
X = np.array([
    [1, 1],
    [2, 3],
    [3, 3]
])
Y = np.array([
    1,
    -1,
    -1
])

model = MyModel(model_type, (2, 1), is_classification=True)

model.train(X, Y, 0.01, 10_000)

model.print_classif(4, 4, 0.01)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 12
#       1 X = np.array([
#       2     [1, 1],
#       3     [2, 3],
#       4     [3, 3]
#       5 ])
#       6 Y = np.array([
#       7     1,
#       8     -1,
#       9     -1
#      10 ])
# ---> 12 model = MyModel(model_type, (2, 1), is_classification=True)
#      14 model.train(X, Y, 0.01, 10_000)
#      16 model.print_classif(4, 4, 0.01)
#
# File ~\OneDrive\Online Sessions\3iabd1\projet annuel\3BigData\interoperability\python_interlop\wrapper\my_lib.py:16, in MyModel.__init__(self, model_type, size, is_classification, is_3_classes, cluster_size, gamma)
#      14     raise ValueError(f"Invalid model type: {model_type}")
#      15 if not isinstance(size, (int, list)):
# ---> 16     raise ValueError("Size must be an integer or a list of integers")
#      17 if cluster_size < 0:
#      18     raise ValueError("Cluster size must be non-negative")
#
# ValueError: Size must be an integer or a list of integers

# %% [markdown]
# ### Linear Multiple :

# %%
X = np.concatenate(
    [np.random.random((50, 2)) * 0.9 + np.array([1, 1]), np.random.random((50, 2)) * 0.9 + np.array([2, 2])])
Y = np.concatenate([np.ones((50, 1)), np.ones((50, 1)) * -1.0])

model = MyModel(model_type, (2, 1), is_classification=True)

model.train(X, Y, 0.01, 10_000)

model.print_classif(4, 4, 0.01)

# %% [markdown]
# ### XOR :

# %%
from interoperability.python_interlop.wrapper import MyModel
import numpy as np

model_type = "mlp"

X = np.array([[1, 0], [0, 1], [0, 0], [1, 1]])
Y = np.array([1, 1, -1, -1])

model = MyModel(model_type, (2,2,1), is_classification=True)

model.train(X, Y, 0.01, 500000000)

model.print_classif(1.2, 1.2, 0.01, -0.2, -0.2)

# %% [markdown]
# ### Cross

# %%
X = np.random.random((500, 2)) * 2.0 - 1.0
Y = np.array([1 if abs(p[0]) <= 0.3 or abs(p[1]) <= 0.3 else -1 for p in X])

#model = MyModel(model_type, (2,4,1), is_classification=True)

#model.train(X, Y, 0.1, 1_000)

#model.print_classif(1, 1, 0.01, -1, -1)

# %% [markdown]
# ### Multi linear 3 classes

# %%
#X = np.random.random((500, 2)) * 2.0 - 1.0
#Y = np.array([[1, 0, 0] if -p[0] - p[1] - 0.5 > 0 > p[1] and p[0] - p[1] - 0.5 < 0 else
 #             [0, 1, 0] if -p[0] - p[1] - 0.5 < 0 < p[1] and p[0] - p[1] - 0.5 < 0 else
  #            [0, 0, 1] if -p[0] - p[1] - 0.5 < 0 < p[0] - p[1] - 0.5 and p[1] < 0 else
   #           [0, 0, 0] for p in X])

#X = X[[not np.all(arr == [0, 0, 0]) for arr in Y]]
#Y = Y[[not np.all(arr == [0, 0, 0]) for arr in Y]]

#model = MyModel(model_type, 2, is_classification=True, is_3_classes=True)

# %%
#model.train(X, Y, 0.1, 10_000_000)

#model.print_classif(1, 1, 0.01, -1, -1)

# %% [markdown]
# ### Multicross :

# %%
#X = np.random.random((1000, 2)) * 2.0 - 1.0
#Y = np.array([[1, 0, 0] if abs(p[0] % 0.5) <= 0.25 < abs(p[1] % 0.5) else [0, 1, 0] if abs(
 #   p[0] % 0.5) > 0.25 >= abs(p[1] % 0.5) else [0, 0, 1] for p in X])

#model = MyModel(model_type, 2, is_classification=True, is_3_classes=True)

#model.train(X, Y, 0.001, 1_000)

#model.print_classif(1, 1, 0.1, -1, -1)

# %% [markdown]
# # Régression
# ### Linéaire simple 2D

# %%
X = np.array([
    [1],
    [2]
])
Y = np.array([
    2,
    3
])

model = MyModel(model_type, (1,1))
print("ini")
model.train(X, Y, 0.1, 1_000)
print("train")
model.print_regression()

# %% [markdown]
# ### Non Linéaire Simple :

# %%
X = np.array([
      [1],
      [2],
      [3]
])
Y = np.array([
      2,
      3,
      2.5
])

model = MyModel(model_type, (1,2,1))

model.train(X, Y, 0.01, 10_000_000)

model.print_regression()

# %% [markdown]
# ### Linéaire simple 3D

# %%
X = np.array([
      [1, 1],
      [2, 2],
      [3, 3]
])
Y = np.array([
      1,
      2,
      3
])

model = MyModel(model_type, (2,1))

model.train(X, Y, 0.1, 1_000)

model.print_regression()

# %% [markdown]
# ### Linéaire tricky 3D

# %%
X = np.array([
      [1, 1],
      [2, 2],
      [3, 3]
])
Y = np.array([
      1,
      2,
      3
])

model = MyModel(model_type, (2,1))

model.train(X, Y, 0.1, 1_000)

model.print_regression()

# %% [markdown]
# ### Non linéaire simple 3D

# %%
X = np.array([
      [1, 0],
      [0, 1],
      [1, 1],
      [0, 0],
])
Y = np.array([
      2,
      1,
      -2,
      -1
])

model = MyModel(model_type, (2,2,1))

model.train(X, Y, 0.1, 1_000)

model.print_regression()
