# %% [markdown]
# # Modèle Perceptron Multi-Couche : Classification
#
# ### Importation de la lib :

# %%
from interoperability.python_interlop.wrapper.my_lib import MyModel
import numpy as np

model_type = "mlp"

# %% [markdown]
# ### Linear simple :

# %%
X_TRAIN = np.array([
    [1, 1],
    [2, 3],
    [3, 3]
])
Y_TRAIN = np.array([
    1,
    -1,
    -1
])

with MyModel(model_type, (2, 1), is_classification=True) as model:
    model.train(
        X_TRAIN,
        Y_TRAIN, 
        learning_rate=0.01,
        epochs=50_000, 
    )
    model.print_classification(4, 4, 0.05)
# Out:
# Initializing the model...
# Training the model...
# begin training the mlp
# finish training the mlp
# Printing the training data...
# Deleting last model...

# %% [markdown]
# ### Linear Multiple :

# %%
X = np.concatenate(
    [np.random.random((50, 2)) * 0.9 + np.array([1, 1]), np.random.random((50, 2)) * 0.9 + np.array([2, 2])])
Y = np.concatenate([np.ones((50, 1)), np.ones((50, 1)) * -1.0])

with MyModel(model_type, (2, 1), is_classification=True) as model:
    model.train(
        X,
        Y,
        learning_rate=0.01,
        epochs=10_000, 
    )
    model.print_classification(4, 4, 0.01)
# Out:
# Initializing the model...
# Training the model...
# begin training the mlp
# finish training the mlp
# Printing the training data...
# Deleting last model...

# %% [markdown]
# ### XOR :

# %%
model_type = "mlp"

X = np.array([[1, 0], [0, 1], [0, 0], [1, 1]])
Y = np.array([1, 1, -1, -1])

with MyModel(model_type, (2,2,1), is_classification=True) as model:
    model.train(
        X,
        Y,
        learning_rate=0.01,
        epochs=50_000, 
    )
    model.print_classification(1.2, 1.2, 0.01, -0.2, -0.2)
# Out:
# Initializing the model...
# Training the model...
# begin training the mlp
# finish training the mlp
# Printing the training data...
# Deleting last model...

# %% [markdown]
# ### Cross

# %%
X = np.random.random((500, 2)) * 2.0 - 1.0
Y = np.array([1 if abs(p[0]) <= 0.3 or abs(p[1]) <= 0.3 else -1 for p in X])

with MyModel(model_type, (2,4,1), is_classification=True) as model:
    model.train(X, Y, 
        learning_rate=0.01, epochs=10_000)
    model.print_classification(1, 1, 0.01, -1, -1)
# Out:
# Initializing the model...
# Training the model...
# begin training the mlp
# finish training the mlp
# Printing the training data...
# Deleting last model...

# %% [markdown]
# ### Multi linear 3 classes

# %%
X = np.random.random((500, 2)) * 2.0 - 1.0
Y = np.array([[1, 0, 0] if -p[0] - p[1] - 0.5 > 0 > p[1] and p[0] - p[1] - 0.5 < 0 else
             [0, 1, 0] if -p[0] - p[1] - 0.5 < 0 < p[1] and p[0] - p[1] - 0.5 < 0 else
             [0, 0, 1] if -p[0] - p[1] - 0.5 < 0 < p[0] - p[1] - 0.5 and p[1] < 0 else
             [0, 0, 0] for p in X])

X = X[[not np.all(arr == [0, 0, 0]) for arr in Y]]
Y = Y[[not np.all(arr == [0, 0, 0]) for arr in Y]]

with MyModel(model_type, (2, 3), is_classification=True, is_3_classes=True) as model:
    model.train(X, Y, 
        learning_rate=0.1, epochs=10_000)
    model.print_classification(1, 1, 0.01, -1, -1)
# Out:
# Initializing the model...
# Deleting last model...
# Training the model...
# begin training the mlp
# finish training the mlp
# Printing the training data...

# %% [markdown]
# ### Multicross :

# %%
X = np.random.random((1000, 2)) * 2.0 - 1.0
Y = np.array([[1, 0, 0] if abs(p[0] % 0.5) <= 0.25 < abs(p[1] % 0.5) else [0, 1, 0] if abs(
   p[0] % 0.5) > 0.25 >= abs(p[1] % 0.5) else [0, 0, 1] for p in X])


with MyModel(model_type, (2, 32, 32, 32, 3), is_classification=True, is_3_classes=True) as model:
    model.train(X, Y,
        learning_rate=0.001, epochs=100_000)
    model.print_classification(1, 1, 0.01, -1, -1)
# Out:
# Initializing the model...
# Deleting last model...
# Training the model...
# begin training the mlp

# %% [markdown]
# # Régression
# ### Linéaire simple 2D

# %%
X = np.array([
    [1],
    [2]
])
Y = np.array([
    2,
    3
])

with MyModel(model_type, (1,1)) as model:
    model.train(X, Y, x_test=X, y_test=Y, 
    learning_rate=0.001, epochs=15_000, 
    log_filename="model.json", model_filename="charbel.json", save_model=False)
    model.print_regression()
# Out:
# Initializing the model...
# Training the model...
# begin training the mlp
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# finish training the mlp
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Model saved successfully to: charbel.json
# Printing the training data...
# Deleting last model...

# %% [markdown]
# ### Non Linéaire Simple 2D :

# %%
X = np.array([
      [1],
      [2],
      [3]
])
Y = np.array([
      2,
      3,
      2.5
])

model = MyModel(model_type, (1,2,1), is_classification=False)

model.train(X, Y, x_test=X, y_test=Y, 
    learning_rate=0.01, epochs=100_000, 
    log_filename="model.json", model_filename="charbel.json")

model.print_regression()
# Out:
# Initializing the model...
# Deleting last model...
# Training the model...
# begin training the mlp
# finish training the mlp
# Printing the training data...

# %% [markdown]
# ### Linéaire simple 3D

# %%
X = np.array([
      [1, 1],
      [2, 2],
      [3, 1]
])
Y = np.array([
      2,
      3,
      2.5
])

model = MyModel(model_type, (2,1))

model.train(X, Y, learning_rate=0.1, epochs=10_000)

model.print_regression_3d()
# Out:
# Initializing the model...
# Deleting last model...
# Training the model...
# begin training the mlp
# finish training the mlp

# %% [markdown]
# ### Linéaire tricky 3D

# %%
X = np.array([
      [1, 1],
      [2, 2],
      [3, 3]
])
Y = np.array([
      1,
      2,
      3
])

model = MyModel(model_type, (2,1))

model.train(X, Y, learning_rate=0.1, epochs=1_000)

model.print_regression_3d()
# Out:
# Initializing the model...
# Training the model...
# begin training the mlp
# finish training the mlp

# %% [markdown]
# ### Non linéaire simple 3D

# %%
X = np.array([
      [1, 0],
      [0, 1],
      [1, 1],
      [0, 0],
])
Y = np.array([
      2,
      1,
      -2,
      -1
])

model = MyModel(model_type, (2,2,1))

model.train(X, Y, learning_rate=0.01, epochs=10_000)

model.print_regression_3d()
# Out:
# Initializing the model...
# Training the model...
# begin training the mlp
# finish training the mlp
