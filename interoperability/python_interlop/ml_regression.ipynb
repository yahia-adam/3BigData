# %% [markdown]
# # Modèle Linéaire : Régression
#
# ## Importation de la bibliothèque

# %%
from interoperability.python_interlop.wrapper import MyModel
import numpy as np

# %% [markdown]
# # Linéaire simple 2D

# %%
X = np.array([
    [1],
    [2]
])
Y = np.array([
    2,
    3
])

model = MyModel("ml", 1)

model.train(X, Y, 0.1, 1_000)

model.print_regression()

# %% [markdown]
# # Linéar Tricky 2d

# %%
X = np.array([
      [1],
      [2],
      [3]
])
Y = np.array([
      2,
      3,
      2.5
])

model = MyModel("ml", 1)

model.train(X, Y, 0.1, 1_000)

model.print_regression()

# %% [markdown]
# # Linear simple 3D

# %%
X = np.array([
      [1, 1],
      [2, 2],
      [3, 3]
])
Y = np.array([
      1,
      2,
      3
])

model = MyModel("ml", 2)

model.train(X, Y, 0.1, 1_000)

model.print_regression()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 16
#      12 model = MyModel("ml", 2)
#      14 model.train(X, Y, 0.1, 1_000)
# ---> 16 model.print_regression()
#
# File ~\RustroverProjects\3BigData\interoperability\python_interlop\wrapper.py:206, in MyModel.print_regression(self, start, size)
#     203 ax = plt.figure().add_subplot(projection='3d')
#     205 ax.scatter(self.train_data[0], self.train_data[1], self.train_data[2])
# --> 206 ax.plot_surface(x[0], x[1], y)
#     208 plt.show()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\mpl_toolkits\mplot3d\axes3d.py:1979, in Axes3D.plot_surface(self, X, Y, Z, norm, vmin, vmax, lightsource, **kwargs)
#    1909 """
#    1910 Create a surface plot.
#    1911
#    (...)
#    1974     Other keyword arguments are forwarded to `.Poly3DCollection`.
#    1975 """
#    1977 had_data = self.has_data()
# -> 1979 if Z.ndim != 2:
#    1980     raise ValueError("Argument Z must be 2-dimensional.")
#    1982 Z = cbook._to_unmasked_float_array(Z)
#
# AttributeError: 'list' object has no attribute 'ndim'
